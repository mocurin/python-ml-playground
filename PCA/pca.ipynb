# %% [markdown]
# # Метод Главных Компонент (PCA)

# %% [markdown]
# Ссылки:
#
# - [Regularized Singular Value Decomposition and Application to Recommender System](https://arxiv.org/pdf/1804.05090.pdf) [arxiv.com]
# - [Как работает метод главных компонент (PCA) на простом примере](https://habr.com/ru/post/304214/) [habr.com]
